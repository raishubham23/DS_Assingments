# %%
# import hierarchical clustering libraries
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import normalize

# %%
airline=pd.read_excel('/content/EastWestAirlines.xlsx',sheet_name='data')
airline
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %% [markdown]
# Data **Exploration**
#
# Descriptive Statistics

# %%
airline.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
airline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
airline=airline.drop(['ID#'],axis=1)
airline.rename(columns={'Award?':'Award'}, inplace=True)
airline
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# Missing Values

# %%
airline.isna().sum()
# Out:
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award                0
# dtype: int64

# %% [markdown]
# Duplicated Values

# %%
# Additionally we check the data for any duplicate values, now this can be an optional check depending on the data being used
airline.duplicated().sum()
# Out:
# 1

# %%
airline[airline.duplicated()]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 3876     1000           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 3876            0                  0                0               1597
#
#       Award
# 3876      0

# %%
airline=airline.drop_duplicates()

# %%
airline[airline.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Balance, Qual_miles, cc1_miles, cc2_miles, cc3_miles, Bonus_miles, Bonus_trans, Flight_miles_12mo, Flight_trans_12, Days_since_enroll, Award]
# Index: []

# %% [markdown]
# Exploratory Data Analysis

# %%
for feature in airline.columns:
    data=airline.copy()
    data[feature].hist(bins=25)
    plt.ylabel('Count')
    plt.title(feature)
    plt.show()

# %%
 # Kernel Density for every feature, singled out
import seaborn as sns
for n in data.columns:
    print(n)
    sns.kdeplot(data[n])
    plt.show()
# Out:
# Balance
# Qual_miles
# cc1_miles
# cc2_miles
# cc3_miles
# Bonus_miles
# Bonus_trans
# Flight_miles_12mo
# Flight_trans_12
# Days_since_enroll
# Award

# %% [markdown]
# Data Preprocessing

# %% [markdown]
# Standard Scaler

# %%
from sklearn.preprocessing import normalize

# %%
airline2_norm=pd.DataFrame(normalize(airline),columns=airline.columns)
airline2_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.970414         0.0   0.000034   0.000034   0.000034     0.006000
# 1     0.940209         0.0   0.000049   0.000049   0.000049     0.010504
# 2     0.981113         0.0   0.000024   0.000024   0.000024     0.097817
# 3     0.904428         0.0   0.000061   0.000061   0.000061     0.030605
# 4     0.912226         0.0   0.000037   0.000009   0.000009     0.404078
# ...        ...         ...        ...        ...        ...          ...
# 3993  0.905810         0.0   0.000049   0.000049   0.000049     0.417949
# 3994  0.999649         0.0   0.000016   0.000016   0.000016     0.015231
# 3995  0.944948         0.0   0.000039   0.000013   0.000013     0.326726
# 3996  0.999592         0.0   0.000018   0.000018   0.000018     0.009104
# 3997  0.907271         0.0   0.000301   0.000301   0.000301     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# Applying different method of Hierarchical clustering

# %%
# Create Dendrograms
#methods=single
plt.figure(figsize=(10, 17))  
dendograms=sch.dendrogram(sch.linkage(airline2_norm,method='single'))

# %%
#methods=complete
plt.figure(figsize=(10, 17))  
dendograms=sch.dendrogram(sch.linkage(airline2_norm,method='complete'))

# %%
#methods=centroid
plt.figure(figsize=(10, 17))  
dendograms=sch.dendrogram(sch.linkage(airline2_norm,method='centroid'))

# %%
#methods=average
plt.figure(figsize=(10, 17))  
dendograms=sch.dendrogram(sch.linkage(airline2_norm,method='average'))

# %%
# Create Clusters (y)
hc=AgglomerativeClustering(n_clusters=5,affinity='euclidean',linkage='complete')
hc
# Out:
# AgglomerativeClustering(affinity='euclidean', linkage='complete', n_clusters=5)

# %%
# save clusters for chart
y_hc = hc.fit_predict(airline2_norm)
y_hc
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# array([0, 0, 0, ..., 0, 0, 0])

# %%
airline['h_clusterid']=y_hc
airline.tail(30)
# Out:
# <ipython-input-21-20f5e8763ef1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   airline['h_clusterid']=y_hc
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 3969    12532           0          1          1          1         2069
# 3970    52584           0          1          1          1         2500
# 3971    20954           0          1          1          1          375
# 3972    35185           0          2          1          1         5957
# 3973    72297           0          3          1          1        16241
# 3974    58387           0          3          1          1        14581
# 3975     9128           0          1          1          1            0
# ...

# %%
airline['h_clusterid'].value_counts()
# Out:
# 0    3086
# 1     509
# 3     197
# 2     137
# 4      69
# Name: h_clusterid, dtype: int64

# %%
airline.groupby('h_clusterid').mean()
# Out:
#                   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# h_clusterid
# 0            85958.186325  163.835386   1.876215   1.012638   1.002916
# 1            49938.428291  109.797642   3.418468   1.031434   1.049116
# 2            15395.744526   93.620438   3.189781   1.021898   1.109489
# 3             7222.208122   10.177665   1.005076   1.000000   1.000000
# 4             1639.043478    0.000000   1.014493   1.000000   1.000000
#
#               Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# h_clusterid
# 0            13503.547959    11.000648         469.272197         1.402787
# 1            40242.673870    18.194499         584.611002         1.722986
# 2            44896.007299    17.065693         560.094891         1.708029
# 3             1067.822335     3.395939          72.786802         0.213198
# 4              661.681159     2.608696          42.753623         0.159420
#
#              Days_since_enroll     Award
# h_clusterid
# ...

# %%
# Plot Clusters
plt.figure(figsize=(10, 7))  
plt.scatter(airline['h_clusterid'],airline['Balance'])

# %% [markdown]
# K-means

# %%
from sklearn.cluster import KMeans

# %%
airline1=airline.iloc[:,:11]
airline1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Normalization function
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

std_df=scaler.fit_transform(airline1)

# %%
std_df
# Out:
# array([[-4.51293870e-01, -1.86322793e-01, -7.69731660e-01, ...,
#         -3.62219103e-01,  1.39523468e+00, -7.67071631e-01],
#        [-5.39604653e-01, -1.86322793e-01, -7.69731660e-01, ...,
#         -3.62219103e-01,  1.37973643e+00, -7.67071631e-01],
#        [-3.20192202e-01, -1.86322793e-01, -7.69731660e-01, ...,
#         -3.62219103e-01,  1.41170157e+00, -7.67071631e-01],
#        ...,
#        [-2.23153612e-04, -1.86322793e-01,  6.82893866e-01, ...,
#         -3.62219103e-01, -1.31599028e+00,  1.30365921e+00],
#        [-1.85776026e-01, -1.86322793e-01, -7.69731660e-01, ...,
#         -9.85832074e-02, -1.31647460e+00, -7.67071631e-01],
#        [-7.00646048e-01, -1.86322793e-01, -7.69731660e-01, ...,
#         -3.62219103e-01, -1.31792757e+00, -7.67071631e-01]])

# %% [markdown]
# Elbow Method

# %%
#WCSS (Within Cluster Sum of Squares)
wcss =[]
for i in range(1,11):
  kmeans = KMeans(n_clusters=i, random_state=0)
  kmeans.fit(std_df)
  wcss.append(kmeans.inertia_)

print(wcss)
plt.plot(range(1,11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS(within cluster sum of squares)')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
#Build Cluster Algorithm
from sklearn.cluster import  KMeans
clusters_new = KMeans(5, random_state=0)
clusters_new.fit(std_df)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=5, random_state=0)

# %%
clusters_new.labels_
# Out:
# array([1, 1, 1, ..., 0, 1, 1], dtype=int32)

# %%
#assign clusters to the data set
airline1['clusters_new']= clusters_new.labels_

# %%
airline1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline1.groupby('clusters_new').agg(['mean'])
# Out:
#                     Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                        mean        mean      mean      mean      mean
# clusters_new
# 0             116739.909449  155.122047  3.704724  1.000000  1.001575
# 1              43869.946906   98.914970  1.225150  1.000000  1.000399
# 2             188752.684848  783.909091  2.181818  1.000000  1.000000
# 3             138061.400000   78.800000  3.466667  1.000000  4.066667
# 4              68876.581395   23.255814  1.139535  2.348837  1.000000
#
#                Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#                       mean        mean              mean            mean
# clusters_new
# 0             39234.801575   18.740945        334.584252        0.997638
# 1              4603.542116    6.809980        196.544910        0.611178
# 2             31282.351515   26.430303       5392.987879       15.612121
# 3             93927.866667   28.066667        506.666667        1.600000
# ...

# %% [markdown]
# Using 5 cluster most of the columns are similar , so we reduse the cluster at 4

# %%
#Build Cluster Algorithm
from sklearn.cluster import  KMeans
clusters_new = KMeans(4, random_state=0)
clusters_new.fit(std_df)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4, random_state=0)

# %%
#assign clusters to the data set
airline1['clusters_new']= clusters_new.labels_

# %%
airline1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline1.groupby('clusters_new').agg(['mean'])
# Out:
#                     Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                        mean        mean      mean      mean      mean
# clusters_new
# 0             194350.181818  778.460606  2.145455  1.036364  1.000000
# 1              44157.999608   97.017228  1.226703  1.019186  1.000392
# 2             138061.400000   78.800000  3.466667  1.000000  4.066667
# 3             116623.795095  157.360759  3.715190  1.002373  1.001582
#
#                Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#                       mean        mean              mean            mean
# clusters_new
# 0             31215.236364   26.890909       5404.654545       15.763636
# 1              4751.874315    6.951840        198.999608        0.620204
# 2             93927.866667   28.066667        506.666667        1.600000
# 3             39451.361551   18.815665        341.890823        1.015823
#
#              Days_since_enroll     Award
# ...

# %%
airline1['clusters_new']=airline1['clusters_new'].replace(0, 'Cluster 1')
airline1['clusters_new']=airline1['clusters_new'].replace(1, 'Cluster 2')
airline1['clusters_new']=airline1['clusters_new'].replace(2, 'Cluster 3')
airline1['clusters_new']=airline1['clusters_new'].replace(3, 'Cluster 4')
airline1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# DBSCAN

# %%
#Import the libraries
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

# %%
airline2=airline.iloc[:,:11]
airline2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# Insert the data value in array format

# %%
data=airline2.values
data
# Out:
# array([[28143,     0,     1, ...,     0,  7000,     0],
#        [19244,     0,     1, ...,     0,  6968,     0],
#        [41354,     0,     1, ...,     0,  7034,     0],
#        ...,
#        [73597,     0,     3, ...,     0,  1402,     1],
#        [54899,     0,     1, ...,     1,  1401,     0],
#        [ 3016,     0,     1, ...,     0,  1398,     0]])

# %%
stscaler = StandardScaler().fit(data)
x = stscaler.transform(data)
x
# Out:
# array([[-4.51293870e-01, -1.86322793e-01, -7.69731660e-01, ...,
#         -3.62219103e-01,  1.39523468e+00, -7.67071631e-01],
#        [-5.39604653e-01, -1.86322793e-01, -7.69731660e-01, ...,
#         -3.62219103e-01,  1.37973643e+00, -7.67071631e-01],
#        [-3.20192202e-01, -1.86322793e-01, -7.69731660e-01, ...,
#         -3.62219103e-01,  1.41170157e+00, -7.67071631e-01],
#        ...,
#        [-2.23153612e-04, -1.86322793e-01,  6.82893866e-01, ...,
#         -3.62219103e-01, -1.31599028e+00,  1.30365921e+00],
#        [-1.85776026e-01, -1.86322793e-01, -7.69731660e-01, ...,
#         -9.85832074e-02, -1.31647460e+00, -7.67071631e-01],
#        [-7.00646048e-01, -1.86322793e-01, -7.69731660e-01, ...,
#         -3.62219103e-01, -1.31792757e+00, -7.67071631e-01]])

# %%
dbscan=DBSCAN(eps=2.5, min_samples=21)
dbscan.fit(x)
# Out:
# DBSCAN(eps=2.5, min_samples=21)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
airline2['Cluster']=pd.DataFrame(dbscan.labels_)
airline2
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline2['Cluster'].value_counts()
# Out:
#  0.0    3789
# -1.0     208
# Name: Cluster, dtype: int64

# %%
x=metrics.silhouette_score(x,dbscan.labels_)
x
# Out:
# 0.6318882008682283

# %%
def dbscan(x,eps,min_samples):
    ss=StandardScaler()
    x=ss.fit_transform(x)
    db=DBSCAN(eps=eps,min_samples=min_samples)
    db.fit(x)
    y_pred=db.fit_predict(x)
    plt.scatter(x[:,0],x[:,1],c=y_pred, cmap='Paired')
    plt.title("DBSCAN")

# %%
dbscan(data,2.5,21)
